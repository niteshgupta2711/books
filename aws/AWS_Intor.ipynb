# %%
# The new console has services section different from another

# %% [markdown]
# ![image.png](attachment:a68dabd5-fc8b-4219-bde4-c64ae0c89387.png)

# %%
# go to your profile 
# and select account
# this is where root users can close their account or edit info create IAm roles etc. or give Root acces to other accounts Under IAm

# %% [markdown]
# ![image.png](attachment:89e8e78e-4072-43a7-9552-59883d86aa81.png)
# ![image.png](attachment:c57fb364-3c7b-4371-a721-8202b5b154cb.png)

# %%
# not everyone gets hands on experience with all the 100+ services

# %%
# Profile ==> account ==> billing preferences

# %% [markdown]
# ![image.png](attachment:9481285a-bc7a-46b9-a9c8-7078dd0abcdc.png)

# %%
# AWS consolidated billing is for Organizations where they can see billing for their sister and parent companies in a hierchal manner

# %%
# # Profile ==> account ==> budget 
# This is where you decide your budgets clearly against a cost or usage

# %%
# Profile ==> Service Quatas
#  rather be a enterprize or a an individual , this is the initia quata everu=yone is provided with

# %%
# free tier Services

# %% [markdown]
# ![image.png](attachment:d966110b-f0a0-4268-b906-3a90265278ed.png)

# %%
# Profile ==> Account ==> cost explorer

# %%
# it is an important thing that can help a lot by the way

# %% [markdown]
# ![image.png](attachment:bfb3af8e-e684-4e74-afb8-5c317117b659.png)

# %%
# as you can see right sizing recommendations
# these provide you with the KPIS - estimated savings if you follow this recommendation that we gave

# %% [markdown]
# ![image.png](attachment:907e44e3-2d94-4ed6-a406-b2ff8bc51d50.png)

# %% [markdown]
# # The three big things That gets costed no matter what cloud you use
# + Compute
# + storage
# + outbound Data transfer

# %% [markdown]
# # EBS

# %% [markdown]
# + elastic block storage
# + this is same as the storage connected to your compute in your laptop
# + EBS is the hard disk storage available for any EC2 instance

# %% [markdown]
# ![image.png](attachment:33c48f1d-8297-432d-8ea1-51378a27084b.png)

# %% [markdown]
# ![image.png](attachment:165d6cda-87f5-4c01-a2ed-ce590ded2185.png)

# %%
# alias created in IAM

# %% [markdown]
# ![image.png](attachment:4d284251-c3be-4f54-9bf3-e53c5cac1f72.png)

# %%
# go to your account section look for IAM user and billing and click edit
# update it

# %% [markdown]
# # go to your cloud watch
# ![image.png](attachment:81684178-4f30-4210-8ac9-5234e030db53.png)

# %%
# creatting billling alarms in cloud watch

# %% [markdown]
# ![image.png](attachment:331f5a3d-a065-4ebf-8e7d-28337cefb08b.png)

# %%
# Select N Virginia if billing is not present in alarms
# under alarms select billing 
# create a new alarm
# new topic set a alarm with name
# Confirm your Email sub from AWS in your gmail after this
# wont work if not confirmed

# %%
# The above serive will work for overall account serices Not just a single service

# %%
# Region to region pricing changes
# some serives from AWS are region specific

# %%
# availability zone  == datacenter one and the same thing
# edige locations are for caching the data

# %%
# each region has two availability zones

# %% [markdown]
# ![image.png](attachment:a6316bb6-6714-4e1d-917e-2e68b7f495c3.png)

# %%
# IAM is a free service
# IAm is a global service free of cost
# as you can see At top right global

# %%
# AWS allows Multifactor Authentication

# %% [markdown]
# ![image.png](attachment:734671fd-957f-417d-ad61-1652be10350c.png)

# %%
# session token sservice(STS)

# %%
# User and group policies are permanent
# where as roles are temporary

# %%
# there are two types of pilicies 
# manage Policies
# custom pilicies

# %%
# create users and groups and assign policies to them

# %% [markdown]
# ![image.png](attachment:c1f2792e-0b99-4619-b873-5ddeaba06b7d.png)

# %%
# go to account settings in IAM , this is where you can change password policoes wriiten

# %%
# you can Allot MFA to users tooo
# got to IAM , go to users, select security and click on manage MFA

# %%
# in profile go to security credentials 
# there you can see MFA
# the way you can change your password
# there you can get your access key and secret key

# %% [markdown]
# ![image.png](attachment:41b45908-4f5c-43f2-9c36-1946e9ee3bec.png)

# %% [markdown]
# ![image.png](attachment:fa0efd92-7aea-4d9d-961c-5e2c10fe40ad.png)

# %% [markdown]
# ![image.png](attachment:f5e7cd52-669a-4afa-aacb-caac260e40dd.png)
